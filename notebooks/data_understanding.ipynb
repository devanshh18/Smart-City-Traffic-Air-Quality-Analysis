# %%
# importing necessary libraries
import pandas as pd
import numpy as np

# %%
# loading datasets
traffic_df = pd.read_csv("../data/raw/indian_smart_traffic_dataset_pro.csv")
air_df = pd.read_csv("../data/raw/realtime_air_quality_index.csv")

# %%
# previewing datasets
traffic_df.head()
# Out:
#              Timestamp        Day  Hour Weather    Area_Type Traffic_Density  \
# 0  2025-09-26 17:03:00     Friday    17   Foggy   Industrial          Medium
# 1  2025-01-02 01:33:00   Thursday     1   Foggy  Residential             Low
# 2  2025-09-03 04:37:00  Wednesday     4   Clear  School Zone             Low
# 3  2025-11-18 01:30:00    Tuesday     1   Rainy   Commercial          Medium
# 4  2025-01-15 06:04:00  Wednesday     6   Foggy   Industrial             Low
#
#    Car_Count  Bike_Count  Truck_Count  Signal_Waiting_Time_Seconds
# 0         32          46            9                           37
# 1         18          17            5                            5
# 2          7          27            5                           10
# 3         34          49           13                           46
# 4          5          18            5                           16

# %%
air_df.head()
# Out:
#   country  state        city                                station  \
# 0   India  Bihar  Kishanganj  SDM Office_Khagra, Kishanganj - BSPCB
# 1   India  Bihar    Motihari        Gandak Colony, Motihari - BSPCB
# 2   India  Bihar    Motihari        Gandak Colony, Motihari - BSPCB
# 3   India  Bihar    Motihari        Gandak Colony, Motihari - BSPCB
# 4   India  Bihar    Motihari        Gandak Colony, Motihari - BSPCB
#
#            last_update  latitude  longitude pollutant_id  pollutant_min  \
# 0  03-03-2026 15:00:00  26.08813  87.938403           CO           17.0
# 1  03-03-2026 15:00:00  26.63086  84.900510          NO2            8.0
# 2  03-03-2026 15:00:00  26.63086  84.900510          SO2            3.0
# 3  03-03-2026 15:00:00  26.63086  84.900510           CO           36.0
# 4  03-03-2026 15:00:00  26.63086  84.900510        OZONE            3.0
#
#    pollutant_max  pollutant_avg
# 0           22.0           21.0
# 1           10.0            9.0
# ...

# %%
# checking dimensions
traffic_df.shape
# Out:
# (15000, 10)

# %%
air_df.shape
# Out:
# (3329, 11)

# %%
# checking column names
traffic_df.columns
# Out:
# Index(['Timestamp', 'Day', 'Hour', 'Weather', 'Area_Type', 'Traffic_Density',
#        'Car_Count', 'Bike_Count', 'Truck_Count',
#        'Signal_Waiting_Time_Seconds'],
#       dtype='object')

# %%
air_df.columns
# Out:
# Index(['country', 'state', 'city', 'station', 'last_update', 'latitude',
#        'longitude', 'pollutant_id', 'pollutant_min', 'pollutant_max',
#        'pollutant_avg'],
#       dtype='object')

# %%
# checking datatypes
traffic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Timestamp                    15000 non-null  object
#  1   Day                          15000 non-null  object
#  2   Hour                         15000 non-null  int64
#  3   Weather                      15000 non-null  object
#  4   Area_Type                    15000 non-null  object
#  5   Traffic_Density              15000 non-null  object
#  6   Car_Count                    15000 non-null  int64
#  7   Bike_Count                   15000 non-null  int64
#  8   Truck_Count                  15000 non-null  int64
#  9   Signal_Waiting_Time_Seconds  15000 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 1.1+ MB

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3329 entries, 0 to 3328
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        3329 non-null   object
#  1   state          3329 non-null   object
#  2   city           3329 non-null   object
#  3   station        3329 non-null   object
#  4   last_update    3329 non-null   object
#  5   latitude       3329 non-null   float64
#  6   longitude      3329 non-null   float64
#  7   pollutant_id   3329 non-null   object
#  8   pollutant_min  3195 non-null   float64
#  9   pollutant_max  3195 non-null   float64
#  10  pollutant_avg  3195 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 286.2+ KB

# %%
# checking missing values
traffic_df.isnull().sum()
# Out:
# Timestamp                      0
# Day                            0
# Hour                           0
# Weather                        0
# Area_Type                      0
# Traffic_Density                0
# Car_Count                      0
# Bike_Count                     0
# Truck_Count                    0
# Signal_Waiting_Time_Seconds    0
# dtype: int64

# %%
air_df.isnull().sum()
# Out:
# country            0
# state              0
# city               0
# station            0
# last_update        0
# latitude           0
# longitude          0
# pollutant_id       0
# pollutant_min    134
# pollutant_max    134
# pollutant_avg    134
# dtype: int64

# %%
# checking duplicate rows
traffic_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
air_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# basic statistics
traffic_df.describe()
# Out:
#                Hour    Car_Count    Bike_Count   Truck_Count  \
# count  15000.000000  15000.00000  15000.000000  15000.000000
# mean      11.544600     35.63300     49.676600     10.370133
# std        6.903892     29.05259     35.872962     10.072479
# min        0.000000      5.00000     10.000000      0.000000
# 25%        6.000000     14.00000     22.000000      3.000000
# 50%       12.000000     26.00000     39.000000      7.000000
# 75%       18.000000     46.00000     65.250000     14.000000
# max       23.000000    120.00000    150.000000     40.000000
#
#        Signal_Waiting_Time_Seconds
# count                 15000.000000
# mean                     44.840533
# std                      43.892298
# min                       5.000000
# 25%                      14.000000
# 50%                      29.000000
# 75%                      55.000000
# max                     180.000000

# %%
air_df.describe()
# Out:
#           latitude    longitude  pollutant_min  pollutant_max  pollutant_avg
# count  3329.000000  3329.000000    3195.000000    3195.000000    3195.000000
# mean     23.309351    78.595090      28.194992      95.054147      54.723005
# std       5.071971     4.914670      31.950795      99.298276      55.009517
# min       8.514909    70.776774       1.000000       1.000000       1.000000
# 25%      19.235581    75.387310       6.000000      20.000000      14.000000
# 50%      23.817487    77.287209      16.000000      64.000000      35.000000
# 75%      27.608912    80.891736      39.000000     124.000000      80.000000
# max      34.066206    94.636574     257.000000     500.000000     393.000000

# %%
# checking unique values
traffic_df['Area_Type'].unique()
# Out:
# array(['Industrial', 'Residential', 'School Zone', 'Commercial',
#        'Highway'], dtype=object)

# %%
traffic_df['Weather'].unique()
# Out:
# array(['Foggy', 'Clear', 'Rainy', 'Stormy', 'Cloudy'], dtype=object)

# %%
traffic_df['Traffic_Density'].unique()
# Out:
# array(['Medium', 'Low', 'High'], dtype=object)

# %%
air_df['city'].unique()
# Out:
# array(['Kishanganj', 'Motihari', 'Munger', 'Muzaffarpur', 'Visakhapatnam',
#        'Naharlagun', 'Byrnihat', 'Guwahati', 'Kadapa',
#        'Rajamahendravaram', 'Tirupati', 'Vijayawada', 'Begusarai',
#        'Bettiah', 'Bhagalpur', 'Bihar Sharif', 'Buxar', 'Sivasagar',
#        'Arrah', 'Aurangabad', 'Nagaon', 'Nalbari', 'Silchar', 'Gaya',
#        'Hajipur', 'Katihar', 'Chhapra', 'Amaravati', 'Raipur', 'Tumidih',
#        'Delhi', 'Sasaram', 'Siwan', 'Chandigarh', 'Bhilai', 'Chhal',
#        'Korba', 'Kunjemura', 'Patna', 'Purnia', 'Saharsa', 'Ahmedabad',
#        'Rajkot', 'Surat', 'Vadodara', 'Vapi', 'Vatva', 'Ambala', 'Jind',
#        'Kaithal', 'Karnal', 'Kurukshetra', 'Mandikhera', 'Faridabad',
#        'Fatehabad', 'Gurugram', 'Bahadurgarh', 'Bhiwani', 'Charkhi Dadri',
#        'Ankleshwar', 'Bhavnagar', 'Gandhinagar', 'Mehsana', 'Dharuhera',
#        'Manesar', 'Narnaul', 'Sirsa', 'Sonipat', 'Yamuna Nagar', 'Baddi',
# ...

# %%
air_df['pollutant_id'].unique()
# Out:
# array(['CO', 'NO2', 'SO2', 'OZONE', 'PM2.5', 'NH3', 'PM10'], dtype=object)

# %%
# connecting mysql to notebook to pull data from mysql --> python
# installing the required library
# !pip install sqlalchemy pymysql

# %%
# another libraries
from sqlalchemy import create_engine

# %%
# creating mysql engine connection
engine = create_engine("mysql+pymysql://root:root@localhost/smart_city_analysis")

# %%
# loading traffic table into pandas
traffic_query = "SELECT * FROM traffic_data"
traffic_df = pd.read_sql(traffic_query, engine)

# %%
traffic_df.head()
# Out:
#    traffic_id           timestamp        day  hour weather    area_type  \
# 0           1 2025-09-26 17:03:00     Friday    17   Foggy   Industrial
# 1           2 2025-01-02 01:33:00   Thursday     1   Foggy  Residential
# 2           3 2025-09-03 04:37:00  Wednesday     4   Clear  School Zone
# 3           4 2025-11-18 01:30:00    Tuesday     1   Rainy   Commercial
# 4           5 2025-01-15 06:04:00  Wednesday     6   Foggy   Industrial
#
#   traffic_density  car_count  bike_count  truck_count  \
# 0          Medium         32          46            9
# 1             Low         18          17            5
# 2             Low          7          27            5
# 3          Medium         34          49           13
# 4             Low          5          18            5
#
#    signal_waiting_time_seconds
# 0                           37
# 1                            5
# 2                           10
# 3                           46
# 4                           16

# %%
air_query = "SELECT * FROM air_quality_data"
air_df = pd.read_sql(air_query, engine)
air_df.head()
# Out:
#    air_id country  state        city                                station  \
# 0       1   India  Bihar  Kishanganj  SDM Office_Khagra, Kishanganj - BSPCB
# 1       2   India  Bihar    Motihari        Gandak Colony, Motihari - BSPCB
# 2       3   India  Bihar    Motihari        Gandak Colony, Motihari - BSPCB
# 3       4   India  Bihar    Motihari        Gandak Colony, Motihari - BSPCB
# 4       5   India  Bihar    Motihari        Gandak Colony, Motihari - BSPCB
#
#            last_update   latitude  longitude pollutant_id pollutant_min  \
# 0  03-03-2026 15:00:00  26.088131  87.938403           CO            17
# 1  03-03-2026 15:00:00  26.630860  84.900510          NO2             8
# 2  03-03-2026 15:00:00  26.630860  84.900510          SO2             3
# 3  03-03-2026 15:00:00  26.630860  84.900510           CO            36
# 4  03-03-2026 15:00:00  26.630860  84.900510        OZONE             3
#
#   pollutant_max pollutant_avg
# 0            22            21
# ...

# %%
traffic_df.shape
# Out:
# (15000, 11)

# %%
air_df.shape
# Out:
# (3329, 12)
